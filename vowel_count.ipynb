# %%
"""prgm for checking vowels"""
def check_vowels(text):
  count=0
  for i in text:
    if i in ['a','e','i','o','u','A','E','I','O','U']:
      count+=1
  return count


sentence=input("enter a text to count the vowels")
print(f"number of vowles  :{check_vowels(sentence) }")
# Out:
# enter a text to count the vowelskritanlmnocti
# number of vowles  :4
