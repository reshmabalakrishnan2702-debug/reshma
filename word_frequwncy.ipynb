# %%
sentence_check=input("enter a sentence")
frequency_counter={}
sentence_check=sentence_check.lower().split()
for i in sentence_check:
    if i in frequency_counter:
        frequency_counter[i]+=1
    else:
        frequency_counter[i]=1
for key,value in frequency_counter.items():
    print(f"{key}:{value}")
# Out:
# enter a sentenceokay okay no no yes yes
# okay:2
# no:2
# yes:2
