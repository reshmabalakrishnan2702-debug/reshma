# %%
"""dictionary disply"""
dict_student={}
for i in range(3):
  stu_name=input("enter students name")
  dict_student[stu_name]=eval(input("enter marks"))
for key,value in dict_student.items():
  print(key,value)
# Out:
# enter students namearcha
# enter marks80
# enter students namenimmy
# enter marks90
# enter students namemeenu
# enter marks100
# archa 80
# nimmy 90
# meenu 100
